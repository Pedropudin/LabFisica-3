# %%
conv_let = {'a':-9,'b':-8,'c':-7,'d':-6,'e':-5,'f':-4,'g':-3,'h':-2,'i':-1,'j':0,'k':1,'l':2,'m':3,'n':4,'o':5,'p':6,'q':7,'r':8,'s':9}
conv_num = {0:-13,1:-12,2:-11,3:-10,4:-9,5:-8,6:-7,7:-6,8:-5,9:-4,10:-3,11:-2,12:-1,13:0,14:1,15:2,16:3,17:4,18:5,19:6,20:7,21:8,22:9,23:10,24:11,25:12,26:13}

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.interpolate import griddata

x, y, z = [],[],[]

placas = open('condutor.csv','r')
for i in range(35):
    val = placas.readline().split(',')
    x.append(conv_let[val[0]])
    y.append(conv_num[int(val[1])])
    z.append(float(val[2][:-1]))

placas.close()

def plot_contour(x,y,z,resolution = 50,contour_method='linear'):
    resolution = str(resolution)+'j'
    X,Y = np.mgrid[min(x):max(x):complex(resolution),   min(y):max(y):complex(resolution)]
    points = [[a,b] for a,b in zip(x,y)]
    Z = griddata(points, z, (X, Y), method=contour_method)
    return X,Y,Z

X,Y,Z = plot_contour(x,y,z,resolution = 50,contour_method='linear')

with plt.style.context("seaborn-white"):
    fig, ax = plt.subplots(figsize=(13,8))
    ax.scatter(x,y, color="black", linewidth=9, edgecolor="ivory", s=50)
    contours=ax.contourf(X,Y,Z,20, cmap='GnBu_r',origin="lower")
    plt.colorbar(contours, shrink=0.67,label="Voltagem")
    plt.clabel(contours, inline=True, fontsize=8, fmt='%.1f')
    
plt.show()

plt.plot(x,y,'ro')
plt.savefig('condutor_pontos.png', format = 'png')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.interpolate import griddata

x, y, z = [],[],[]

placas = open('pontuais.csv','r')
for i in range(40):
    val = placas.readline().split(',')
    x.append(conv_let[val[0]])
    y.append(conv_num[int(val[1])])
    z.append(float(val[2][:-1]))

placas.close()

def plot_contour(x,y,z,resolution = 50,contour_method='linear'):
    resolution = str(resolution)+'j'
    X,Y = np.mgrid[min(x):max(x):complex(resolution),   min(y):max(y):complex(resolution)]
    points = [[a,b] for a,b in zip(x,y)]
    Z = griddata(points, z, (X, Y), method=contour_method)
    return X,Y,Z

X,Y,Z = plot_contour(x,y,z,resolution = 50,contour_method='linear')

with plt.style.context("seaborn-white"):
    fig, ax = plt.subplots(figsize=(13,8))
    ax.scatter(x,y, color="black", linewidth=9, edgecolor="ivory", s=50)
    contours=ax.contourf(X,Y,Z,20, cmap='GnBu_r',origin="lower")
    plt.colorbar(contours, shrink=0.67,label="Voltagem")
    plt.clabel(contours, inline=True, fontsize=8, fmt='%.1f')
    
#plt.show()

#plt.plot(x,y,'ro')
#plt.savefig('pontuais_pontos.png', format = 'png')
#plt.show()

pontos = {}

for ind,valx in enumerate(x):
    valy = y[ind]
    valz = z[ind]
    
    pontos[(valx,valy)] = valz

# %%
vol = []
for pos in pontos:
    if pos[0]==0:
        vol.append(pontos[pos])
vol.sort()
print(vol)

plt.plot(vol)
plt.show()
# Out:
# [3.67, 4.05, 4.41, 4.73, 4.98, 5.27, 5.73, 6.06, 6.45]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy.interpolate import griddata

x, y, z = [],[],[]

placas = open('placas_paralelas.csv','r')
for i in range(57):
    val = placas.readline().split(',')
    x.append(conv_let[val[0]])
    y.append(conv_num[int(val[1])])
    z.append(float(val[2][:-1]))

placas.close()

def plot_contour(x,y,z,resolution = 50,contour_method='linear'):
    resolution = str(resolution)+'j'
    X,Y = np.mgrid[min(x):max(x):complex(resolution),   min(y):max(y):complex(resolution)]
    points = [[a,b] for a,b in zip(x,y)]
    Z = griddata(points, z, (X, Y), method=contour_method)
    return X,Y,Z

X,Y,Z = plot_contour(x,y,z,resolution = 50,contour_method='linear')

with plt.style.context("seaborn-white"):
    fig, ax = plt.subplots(figsize=(13,8))
    ax.scatter(x,y, color="black", linewidth=9, edgecolor="ivory", s=50)
    contours=ax.contourf(X,Y,Z,20, cmap='GnBu_r',origin="lower")
    plt.colorbar(contours, shrink=0.67,label="Voltagem")
    plt.clabel(contours, inline=True, fontsize=8, fmt='%.1f')
    
plt.show()

#plt.plot(x,y,'ro')
plt.savefig('placas_paralelas_pontos.png', format = 'png')
#plt.show()

pontos = {}

for ind,valx in enumerate(x):
    valy = y[ind]
    valz = z[ind]
    
    pontos[(valx,valy)] = valz

# %%
vol = []
for pos in pontos:
    if pos[0]==0:
        vol.append(pontos[pos])
vol.sort()
print(vol)

plt.plot(vol)
plt.show()
# Out:
# [0.63, 1.58, 2.5]
